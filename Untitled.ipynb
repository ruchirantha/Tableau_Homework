# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('201607-citibike-tripdata.csv')
df.head()
# Out:
#    tripduration      starttime       stoptime  start station id  \
# 0           704  7/1/2016 0:00  7/1/2016 0:11               459
# 1           492  7/1/2016 0:00  7/1/2016 0:08               293
# 2           191  7/1/2016 0:00  7/1/2016 0:03              3090
# 3           687  7/1/2016 0:00  7/1/2016 0:11               459
# 4           609  7/1/2016 0:00  7/1/2016 0:10               284
#
#       start station name  start station latitude  start station longitude  \
# 0       W 20 St & 11 Ave               40.746745               -74.007756
# 1  Lafayette St & E 8 St               40.730287               -73.990765
# 2    N 8 St & Driggs Ave               40.717746               -73.956001
# 3       W 20 St & 11 Ave               40.746745               -74.007756
# 4  Greenwich Ave & 8 Ave               40.739017               -74.002638
#
#    end station id             end station name  end station latitude  \
# ...

# %%
df.replace('', np.nan, inplace=True)
df.head()
# Out:
#    tripduration      starttime       stoptime  start station id  \
# 0           704  7/1/2016 0:00  7/1/2016 0:11               459
# 1           492  7/1/2016 0:00  7/1/2016 0:08               293
# 2           191  7/1/2016 0:00  7/1/2016 0:03              3090
# 3           687  7/1/2016 0:00  7/1/2016 0:11               459
# 4           609  7/1/2016 0:00  7/1/2016 0:10               284
#
#       start station name  start station latitude  start station longitude  \
# 0       W 20 St & 11 Ave               40.746745               -74.007756
# 1  Lafayette St & E 8 St               40.730287               -73.990765
# 2    N 8 St & Driggs Ave               40.717746               -73.956001
# 3       W 20 St & 11 Ave               40.746745               -74.007756
# 4  Greenwich Ave & 8 Ave               40.739017               -74.002638
#
#    end station id             end station name  end station latitude  \
# ...

# %%
df.dropna(subset=['birth year'], inplace=True)
df.head()
# Out:
#    tripduration      starttime       stoptime  start station id  \
# 1           492  7/1/2016 0:00  7/1/2016 0:08               293
# 2           191  7/1/2016 0:00  7/1/2016 0:03              3090
# 5           672  7/1/2016 0:00  7/1/2016 0:11               459
# 6           466  7/1/2016 0:00  7/1/2016 0:08               128
# 7           556  7/1/2016 0:00  7/1/2016 0:10               433
#
#          start station name  start station latitude  start station longitude  \
# 1     Lafayette St & E 8 St               40.730287               -73.990765
# 2       N 8 St & Driggs Ave               40.717746               -73.956001
# 5          W 20 St & 11 Ave               40.746745               -74.007756
# 6  MacDougal St & Prince St               40.727103               -74.002971
# 7        E 13 St & Avenue A               40.729554               -73.980572
#
#    end station id             end station name  end station latitude  \
# ...

# %%
df.to_csv('2016_filtered_data.csv')
